# %% [markdown]
# # The Dinosaur Network
# ## Based on matrix_dino_net.py
#
# ### Goal:
# To use a spiking neural network to play the Google Dinosaur game.
#
# TODO: Use PyTorch (GPUs)
# TODO: Steal Ivyer's code for weight matrices bc it's quite compact/nice

# %%
# TODO: Some possible directions:
# Visualize the connections and weights (also add saving of neural nets)
# Start by saving most fit of all time, then maybe go to most fit of each generation. Save spiking activity as well?
# Need to save the input weights as well
# Penalize extra jumps
# Change speed of obstacles and see if model can learn
# See how number of neurons affects the training process (scaling laws)
# Specifying that neurons that receive input cannot give output
# Try combining output of multiple neurons to provide final output
# Specifying neuron types
# Vary frequency of obstacles (keep speed constant though) - to make sure model is truly responding to the input
# Use other training models


# Read about LIF neurons for Yuqing
# Integrate Ivyer's code as a library, work through initial issues
# Potentially change the method of input
# Look into reinforcement learning, STDP, altering the network in real time...? (W a gui? cli? api?)

# %%
import numpy as np
import pygame
import time
import random
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.12.5)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
class SpikingNeuron:
    def __init__(self, threshold=0.5, decay=0.9):
        self.potential = 0.0
        self.threshold = threshold
        self.decay = decay

    def receive_input(self, input_value):
        self.potential += input_value

    def step(self):
        # Neuron fires if potential exceeds threshold
        if self.potential >= self.threshold:
            self.potential = 0  # Reset after spike
            return 1  # Spike (output 1)
        else:
            # Decay potential over time
            self.potential *= self.decay
            return 0  # No spike (output 0)

# %%
class RecurrentSpikingNeuralNetwork:
    # Each neuron has set threshold and decay
    def __init__(self, num_inputs, num_neurons):
        self.neurons = [SpikingNeuron() for _ in range(num_neurons)] # List of neurons
        
        # Input matrix
        self.input_matrix = np.zeros((num_neurons, num_inputs)) # Shape: 1 row for each neuron, 1 column for each input
        # 1 input -> 1 neuron
        for j in range(num_inputs):
            i = int(np.floor(np.random.random() * num_neurons))
            self.input_matrix[i, j] = np.random.random()

        # Connection matrix
        self.connection_matrix = np.zeros((num_neurons, num_neurons))
        for i in range(num_neurons):
            for j in range(num_neurons):
                # 20% chance for each connection to form
                if np.random.random() >= 0.8:
                    # The connection weights are initially random
                    self.connection_matrix[i, j] = np.random.random()
        
        # Make sure each neuron has a least 1 connection:
        for j in range(num_neurons):
            # Go through each column, if the column is all zeroes then the neuron has no outputs
            if np.sum(self.connection_matrix[:, j]) == 0:
                i = int(np.floor(np.random.random() * num_neurons))
                self.connection_matrix[i, j] = np.random.random()

        self.spikes = np.zeros((num_neurons))

    def forward(self, inputs):        
        assert len(inputs) == len(self.input_matrix[0]), 'The network was passed an unexpected number of inputs. Check the initialization of the network or the shape of the input.'

        # Every time step:
        # All spikes are calculated & recorded. Place into spike map
        # All neurons decay
        self.spikes = np.zeros((len(self.neurons)))
        for i, neuron in enumerate(self.neurons):
            spike = neuron.step()
            self.spikes[i] = spike

        # All inputs are sent to their proper neuron, multiplied by their proper weight
        in_vec = np.array(inputs).reshape(-1,1) # Turn inputs into a vertical vector
        in_weighted = (self.input_matrix @ in_vec).reshape(-1) # Calculate and make it a 1d array for ease of looping
        for i, input in enumerate(in_weighted):
            self.neurons[i].receive_input(input)

        # All connections are resolved
        con_vec = self.spikes.reshape(-1,1) # Turn inputs into a vertical vector
        con_weighted = (self.connection_matrix @ con_vec).reshape(-1) # Calculate and make it a 1d array for ease of looping
        for i, val in enumerate(con_weighted):
            self.neurons[i].receive_input(val)

        # What value to return?
        return self.spikes

    def mutate(self, mutation_rate=0.1):
        # Random mutation for evolutionary algorithm
        for i in range(self.input_matrix.shape[0]):
            for j in range(self.input_matrix.shape[1]):
                if self.input_matrix[i, j] != 0:
                    self.input_matrix[i, j] += np.random.normal() * 0.1
                else:
                    # Allow creation of new input connections!
                    if np.random.random() >= 0.995:
                        self.input_matrix[i, j] += np.random.normal() * 0.1
        
        for i in range(self.connection_matrix.shape[0]):
            for j in range(self.connection_matrix.shape[1]):
                if self.connection_matrix[i, j] != 0:
                    self.connection_matrix[i, j] += np.random.normal() * 0.1
                else:
                    # Allow creation of new connections!
                    if np.random.random() >= 0.995:
                        self.connection_matrix[i, j] += np.random.normal() * 0.1

    def visualize(self, screen):
        # TODO: Broken I think

        # Need to visualize inputs
        # Need to visualize neurons
        # Need to visualize connections
        BLACK = (0, 0, 0)
        # Draw neural network
        
        num_neurons = len(self.neurons)
        if num_neurons % 2 == 0:
            for i in range(num_neurons//2):
                pygame.draw.circle(screen, BLACK, (720 - (50*i), 50), 15, width=int(self.spikes[2*i]))
                pygame.draw.circle(screen, BLACK, (720 - (50*i), 100), 15, width=int(self.spikes[2*i + 1]))
        else:
            for i in range(num_neurons//2):
                pygame.draw.circle(screen, BLACK, (745 - (50*i), 50), 15, width=int(self.spikes[2*i]))
                pygame.draw.circle(screen, BLACK, (720 - (50*i), 100), 15, width=int(self.spikes[2*i + 1]))
            pygame.draw.circle(screen, BLACK, (745 - (50*(num_neurons // 2)), 50), 15, width=int(self.spikes[-1]))
        # TODO: Visualize odd number of neurons


        # obs = 1 if self.obstacle_x == 250 else 0
        # pygame.draw.circle(screen, (255, 0, 0), (670, 150), 15, width=obs)

    def save(self, filename):
        if not filename.endswith('.csv'):
            filename = filename + '.csv'
        
        data = [[''],]

        for i in range(len(self.neurons)):
            # Set up connection format
            data[0].append(str(chr(65 + i)))
            data.append([chr(65 + i), *list(0 for _ in range(len(self.neurons)))])


        data = np.array(data)
        data[1:, 1:] = self.connection_matrix

        np.savetxt(filename, data, fmt='%s', delimiter=';')

        return filename

# %%
class DinosaurGame:
    def __init__(self, maximum = None):
        self.time = 0
        self.alive = True
        # Colors
        self.WHITE = (255, 255, 255)
        self.BLACK = (0, 0, 0)
        # Dinosaur settings
        self.dino_size = 50
        self.dino_x = 80
        self.dino_y = HEIGHT - self.dino_size - 40
        self.dino_vel_y = 0
        self.gravity = 2
        self.jumping = False

        # Obstacle settings
        self.obstacle_width = 20
        self.obstacle_height = 50
        self.obstacle_x = WIDTH
        self.obstacle_y = HEIGHT - self.obstacle_height - 40
        self.obstacle_speed = 10

        # Game settings
        self.running = True
        self.jumping = False
        self.score = 0
        self.font = pygame.font.Font(None, 36)

        # Game loop
        self.clock = pygame.time.Clock()

        if maximum:
            self.maximum = maximum
        else:
            self.maximum = False


    def get_input(self):
        # Return input: 1 if obstacle, 0 if not (obstacles appear every few timesteps)
        return [1 if self.obstacle_x == 350 else 0]

    def step(self, action):
        # Event handling
        # AI output: jump or not (each frame ig)
        if action == 1 and not self.jumping:
            self.jumping = True
            self.dino_vel_y = -20

        # Dinosaur movement (jumping)
        if self.jumping:
            self.dino_y += self.dino_vel_y
            self.dino_vel_y += self.gravity
            if self.dino_y >= HEIGHT - self.dino_size - 40:
                self.dino_y = HEIGHT - self.dino_size - 40
                self.jumping = False

        # Obstacle movement: Resets the same obstacle
        # Can give AI input every time this if triggers
        self.obstacle_x -= self.obstacle_speed
        if self.obstacle_x < -self.obstacle_width:
            self.obstacle_x = WIDTH
            self.score += 1

        # Collision detection
        dino_rect = pygame.Rect(self.dino_x, self.dino_y, self.dino_size, self.dino_size)
        obstacle_rect = pygame.Rect(self.obstacle_x, self.obstacle_y, self.obstacle_width, self.obstacle_height)
        if dino_rect.colliderect(obstacle_rect):
            self.alive = False

        if self.maximum:
            if self.score >= self.maximum:
                self.alive = False

        self.time += 1

        # # Speeding up
        # if self.time % 1000 == 0:
        #     self.obstacle_speed += 1
        # # Debug
        # if generation >= 30:
        #     time.sleep(0.00001)
        # time.sleep(0.001)
        # print(f'time: {self.time} action: {action}\ndino_y: {self.dino_y}\ndino_vel_y: {self.dino_vel_y}\njumping: {self.jumping}')

    def visualize(self, screen, inputs):
        # Draws game state in pygame

        # Collision detection
        dino_rect = pygame.Rect(self.dino_x, self.dino_y, self.dino_size, self.dino_size)
        obstacle_rect = pygame.Rect(self.obstacle_x, self.obstacle_y, self.obstacle_width, self.obstacle_height)

        # Draw dinosaur and obstacle
        pygame.draw.rect(screen, self.BLACK, dino_rect)
        pygame.draw.rect(screen, self.BLACK, obstacle_rect)

        # Draw score
        score_text = self.font.render(f"Score: {self.score}", True, self.BLACK)
        screen.blit(score_text, (10, 10))

# %%
class EvolutionaryAlgorithm:
    def __init__(self, population_size=20, mutation_rate=0.1, num_neurons=17):
        self.population_size = population_size
        self.mutation_rate = mutation_rate
        self.num_neurons = num_neurons
        self.population = [RecurrentSpikingNeuralNetwork(num_inputs=1, num_neurons=self.num_neurons) for _ in range(population_size)]
    
    def evaluate_fitness(self, network, screen=None, maximum=False):
        game = DinosaurGame(maximum=maximum)
        total = 0
        while game.alive:
            inputs = game.get_input()
            outputs = network.forward(inputs)
            total += np.sum(outputs)
            game.step(outputs[0])

            # Visualize
            if screen:
                screen.fill((255, 255, 255))
                game.visualize(screen, outputs)
                network.visualize(screen)
                # Update display
                pygame.display.flip()
                time.sleep(0.01)

        # if total > 1:
        #     print(total)
        return game.score

    def run_generation(self, screen=None, maximum=False):
        # Evaluate fitness of each network
        fitness_scores = [self.evaluate_fitness(network, screen=screen, maximum=maximum) for network in self.population]
        
        # Select top-performing networks
        sorted_population = [network for _, network in sorted(zip(fitness_scores, self.population), key=lambda tuple: tuple[0], reverse=True)]
        self.population = sorted_population[:self.population_size // 2]
        
        # Repopulate with mutated copies
        while len(self.population) < self.population_size:
            parent = random.choice(self.population)
            child = RecurrentSpikingNeuralNetwork(num_inputs=1, num_neurons=self.num_neurons)
            child.input_matrix = np.copy(parent.input_matrix)
            child.connection_matrix = np.copy(parent.connection_matrix)
            child.mutate(self.mutation_rate)
            self.population.append(child)
        
        return max(fitness_scores)

# %%
def main():
    # Initialize Pygame
    pygame.init()
    # Screen dimensions
    global WIDTH, HEIGHT, font
    WIDTH, HEIGHT = 800, 400
    screen = pygame.display.set_mode((WIDTH, HEIGHT))
    pygame.display.set_caption("Dino Game")
    font = pygame.font.Font(None, 36)

    # Run evolutionary algorithm
    ea = EvolutionaryAlgorithm(population_size=10, mutation_rate=60)
    global generations
    generations = 10001
    max_score = 0
    for generation in range(generations):
        max_fitness = ea.run_generation(screen=None, maximum=100)
        print(f"Generation {generation}, Max Fitness: {max_fitness}, Max Score: {max_score}")
        if max_fitness > max_score:
            max_score = max_fitness
            screen = pygame.display.set_mode((WIDTH, HEIGHT))
            print(ea.population[0].save(f'network: {time.asctime()}'))
            ea.evaluate_fitness(ea.population[0], screen=screen, maximum=100)
        # At 10000th generation, if no solve yet, restart
        if generation >= 10000:
            main()

# %%
main()
# Out:
# Generation 0, Max Fitness: 0, Max Score: 0
# Generation 1, Max Fitness: 3, Max Score: 0
# network: Thu Feb 13 21:42:49 2025.csv
# Generation 2, Max Fitness: 3, Max Score: 3
# Generation 3, Max Fitness: 3, Max Score: 3
# Generation 4, Max Fitness: 3, Max Score: 3
# Generation 5, Max Fitness: 9, Max Score: 3
# network: Thu Feb 13 21:42:53 2025.csv
# Generation 6, Max Fitness: 3, Max Score: 9
# Generation 7, Max Fitness: 8, Max Score: 9
# Generation 8, Max Fitness: 4, Max Score: 9
# Generation 9, Max Fitness: 4, Max Score: 9
# Generation 10, Max Fitness: 4, Max Score: 9
# Generation 11, Max Fitness: 4, Max Score: 9
# Generation 12, Max Fitness: 4, Max Score: 9
# Generation 13, Max Fitness: 4, Max Score: 9
# Generation 14, Max Fitness: 4, Max Score: 9
# Generation 15, Max Fitness: 4, Max Score: 9
# Generation 16, Max Fitness: 4, Max Score: 9
# Generation 17, Max Fitness: 4, Max Score: 9
# Generation 18, Max Fitness: 4, Max Score: 9
# Generation 19, Max Fitness: 4, Max Score: 9
# Generation 20, Max Fitness: 4, Max Score: 9
# Generation 21, Max Fitness: 4, Max Score: 9
# Generation 22, Max Fitness: 4, Max Score: 9
# Generation 23, Max Fitness: 10, Max Score: 9
# network: Thu Feb 13 21:42:54 2025.csv
# Generation 24, Max Fitness: 4, Max Score: 10
# Generation 25, Max Fitness: 4, Max Score: 10
# Generation 26, Max Fitness: 4, Max Score: 10
# Generation 27, Max Fitness: 4, Max Score: 10
# Generation 28, Max Fitness: 4, Max Score: 10
# Generation 29, Max Fitness: 4, Max Score: 10
# Generation 30, Max Fitness: 4, Max Score: 10
# Generation 31, Max Fitness: 4, Max Score: 10
# Generation 32, Max Fitness: 11, Max Score: 10
# network: Thu Feb 13 21:42:56 2025.csv
# Generation 33, Max Fitness: 4, Max Score: 11
# Generation 34, Max Fitness: 7, Max Score: 11
# Generation 35, Max Fitness: 4, Max Score: 11
# Generation 36, Max Fitness: 9, Max Score: 11
# Generation 37, Max Fitness: 4, Max Score: 11
# Generation 38, Max Fitness: 11, Max Score: 11
# Generation 39, Max Fitness: 10, Max Score: 11
# Generation 40, Max Fitness: 8, Max Score: 11
# Generation 41, Max Fitness: 4, Max Score: 11
# Generation 42, Max Fitness: 4, Max Score: 11
# Generation 43, Max Fitness: 10, Max Score: 11
# Generation 44, Max Fitness: 4, Max Score: 11
# Generation 45, Max Fitness: 4, Max Score: 11
# Generation 46, Max Fitness: 11, Max Score: 11
# Generation 47, Max Fitness: 11, Max Score: 11
# Generation 48, Max Fitness: 4, Max Score: 11
# Generation 49, Max Fitness: 4, Max Score: 11
# Generation 50, Max Fitness: 4, Max Score: 11
# Generation 51, Max Fitness: 11, Max Score: 11
# Generation 52, Max Fitness: 4, Max Score: 11
# Generation 53, Max Fitness: 11, Max Score: 11
# Generation 54, Max Fitness: 11, Max Score: 11
# Generation 55, Max Fitness: 4, Max Score: 11
# Generation 56, Max Fitness: 4, Max Score: 11
# Generation 57, Max Fitness: 8, Max Score: 11
# Generation 58, Max Fitness: 9, Max Score: 11
# Generation 59, Max Fitness: 8, Max Score: 11
# Generation 60, Max Fitness: 4, Max Score: 11
# Generation 61, Max Fitness: 4, Max Score: 11
# Generation 62, Max Fitness: 4, Max Score: 11
# Generation 63, Max Fitness: 4, Max Score: 11
# Generation 64, Max Fitness: 4, Max Score: 11
# Generation 65, Max Fitness: 4, Max Score: 11
# Generation 66, Max Fitness: 4, Max Score: 11
# Generation 67, Max Fitness: 4, Max Score: 11
# Generation 68, Max Fitness: 4, Max Score: 11
# Generation 69, Max Fitness: 4, Max Score: 11
# Generation 70, Max Fitness: 4, Max Score: 11
# Generation 71, Max Fitness: 4, Max Score: 11
# Generation 72, Max Fitness: 4, Max Score: 11
# Generation 73, Max Fitness: 4, Max Score: 11
# Generation 74, Max Fitness: 4, Max Score: 11
# Generation 75, Max Fitness: 4, Max Score: 11
# Generation 76, Max Fitness: 10, Max Score: 11
# Generation 77, Max Fitness: 11, Max Score: 11
# Generation 78, Max Fitness: 8, Max Score: 11
# Generation 79, Max Fitness: 4, Max Score: 11
# Generation 80, Max Fitness: 4, Max Score: 11
# Generation 81, Max Fitness: 4, Max Score: 11
# Generation 82, Max Fitness: 4, Max Score: 11
# Generation 83, Max Fitness: 10, Max Score: 11
# Generation 84, Max Fitness: 4, Max Score: 11
# Generation 85, Max Fitness: 8, Max Score: 11
# Generation 86, Max Fitness: 4, Max Score: 11
# Generation 87, Max Fitness: 10, Max Score: 11
# Generation 88, Max Fitness: 4, Max Score: 11
# Generation 89, Max Fitness: 4, Max Score: 11
# Generation 90, Max Fitness: 4, Max Score: 11
# Generation 91, Max Fitness: 11, Max Score: 11
# Generation 92, Max Fitness: 4, Max Score: 11
# Generation 93, Max Fitness: 4, Max Score: 11
# Generation 94, Max Fitness: 4, Max Score: 11
# Generation 95, Max Fitness: 4, Max Score: 11
# Generation 96, Max Fitness: 4, Max Score: 11
# Generation 97, Max Fitness: 9, Max Score: 11
# Generation 98, Max Fitness: 4, Max Score: 11
# Generation 99, Max Fitness: 4, Max Score: 11
# Generation 100, Max Fitness: 4, Max Score: 11
# Generation 101, Max Fitness: 4, Max Score: 11
# Generation 102, Max Fitness: 4, Max Score: 11
# Generation 103, Max Fitness: 11, Max Score: 11
# Generation 104, Max Fitness: 4, Max Score: 11
# Generation 105, Max Fitness: 4, Max Score: 11
# Generation 106, Max Fitness: 8, Max Score: 11
# Generation 107, Max Fitness: 4, Max Score: 11
# Generation 108, Max Fitness: 4, Max Score: 11
# Generation 109, Max Fitness: 11, Max Score: 11
# Generation 110, Max Fitness: 4, Max Score: 11
# Generation 111, Max Fitness: 4, Max Score: 11
# Generation 112, Max Fitness: 4, Max Score: 11
# Generation 113, Max Fitness: 4, Max Score: 11
# Generation 114, Max Fitness: 7, Max Score: 11
# Generation 115, Max Fitness: 4, Max Score: 11
# Generation 116, Max Fitness: 4, Max Score: 11
# Generation 117, Max Fitness: 9, Max Score: 11
# Generation 118, Max Fitness: 4, Max Score: 11
# Generation 119, Max Fitness: 4, Max Score: 11
# Generation 120, Max Fitness: 4, Max Score: 11
# Generation 121, Max Fitness: 10, Max Score: 11
# Generation 122, Max Fitness: 11, Max Score: 11
# Generation 123, Max Fitness: 4, Max Score: 11
# Generation 124, Max Fitness: 4, Max Score: 11
# Generation 125, Max Fitness: 10, Max Score: 11
# Generation 126, Max Fitness: 4, Max Score: 11
# Generation 127, Max Fitness: 4, Max Score: 11
# Generation 128, Max Fitness: 4, Max Score: 11
# Generation 129, Max Fitness: 11, Max Score: 11
# Generation 130, Max Fitness: 9, Max Score: 11
# Generation 131, Max Fitness: 4, Max Score: 11
# Generation 132, Max Fitness: 4, Max Score: 11
# Generation 133, Max Fitness: 4, Max Score: 11
# Generation 134, Max Fitness: 4, Max Score: 11
# Generation 135, Max Fitness: 4, Max Score: 11
# Generation 136, Max Fitness: 4, Max Score: 11
# Generation 137, Max Fitness: 10, Max Score: 11
# Generation 138, Max Fitness: 4, Max Score: 11
# Generation 139, Max Fitness: 4, Max Score: 11
# Generation 140, Max Fitness: 4, Max Score: 11
# Generation 141, Max Fitness: 11, Max Score: 11
# Generation 142, Max Fitness: 4, Max Score: 11
# Generation 143, Max Fitness: 4, Max Score: 11
# Generation 144, Max Fitness: 4, Max Score: 11
# Generation 145, Max Fitness: 4, Max Score: 11
# Generation 146, Max Fitness: 4, Max Score: 11
# Generation 147, Max Fitness: 4, Max Score: 11
# Generation 148, Max Fitness: 4, Max Score: 11
# Generation 149, Max Fitness: 4, Max Score: 11
# Generation 150, Max Fitness: 10, Max Score: 11
# Generation 151, Max Fitness: 5, Max Score: 11
# Generation 152, Max Fitness: 4, Max Score: 11
# Generation 153, Max Fitness: 4, Max Score: 11
# Generation 154, Max Fitness: 4, Max Score: 11
# Generation 155, Max Fitness: 9, Max Score: 11
# Generation 156, Max Fitness: 4, Max Score: 11
# Generation 157, Max Fitness: 9, Max Score: 11
# Generation 158, Max Fitness: 4, Max Score: 11
# Generation 159, Max Fitness: 4, Max Score: 11
# Generation 160, Max Fitness: 4, Max Score: 11
# Generation 161, Max Fitness: 9, Max Score: 11
# Generation 162, Max Fitness: 10, Max Score: 11
# Generation 163, Max Fitness: 4, Max Score: 11
# Generation 164, Max Fitness: 4, Max Score: 11
# Generation 165, Max Fitness: 9, Max Score: 11
# Generation 166, Max Fitness: 4, Max Score: 11
# Generation 167, Max Fitness: 4, Max Score: 11
# Generation 168, Max Fitness: 4, Max Score: 11
# Generation 169, Max Fitness: 4, Max Score: 11
# Generation 170, Max Fitness: 4, Max Score: 11
# Generation 171, Max Fitness: 4, Max Score: 11
# Generation 172, Max Fitness: 4, Max Score: 11
# Generation 173, Max Fitness: 4, Max Score: 11
# Generation 174, Max Fitness: 4, Max Score: 11
# Generation 175, Max Fitness: 4, Max Score: 11
# Generation 176, Max Fitness: 4, Max Score: 11
# Generation 177, Max Fitness: 10, Max Score: 11
# Generation 178, Max Fitness: 4, Max Score: 11
# Generation 179, Max Fitness: 4, Max Score: 11
# Generation 180, Max Fitness: 4, Max Score: 11
# Generation 181, Max Fitness: 11, Max Score: 11
# Generation 182, Max Fitness: 4, Max Score: 11
# Generation 183, Max Fitness: 4, Max Score: 11
# Generation 184, Max Fitness: 9, Max Score: 11
# Generation 185, Max Fitness: 4, Max Score: 11
# Generation 186, Max Fitness: 4, Max Score: 11
# Generation 187, Max Fitness: 4, Max Score: 11
# Generation 188, Max Fitness: 4, Max Score: 11
# Generation 189, Max Fitness: 4, Max Score: 11
# Generation 190, Max Fitness: 4, Max Score: 11
# Generation 191, Max Fitness: 4, Max Score: 11
# Generation 192, Max Fitness: 4, Max Score: 11
# Generation 193, Max Fitness: 8, Max Score: 11
# Generation 194, Max Fitness: 4, Max Score: 11
# Generation 195, Max Fitness: 4, Max Score: 11
# Generation 196, Max Fitness: 4, Max Score: 11
# Generation 197, Max Fitness: 9, Max Score: 11
# Generation 198, Max Fitness: 4, Max Score: 11
# Generation 199, Max Fitness: 7, Max Score: 11
# Generation 200, Max Fitness: 4, Max Score: 11
# Generation 201, Max Fitness: 4, Max Score: 11
# Generation 202, Max Fitness: 4, Max Score: 11
# Generation 203, Max Fitness: 4, Max Score: 11
# Generation 204, Max Fitness: 4, Max Score: 11
# Generation 205, Max Fitness: 4, Max Score: 11
# Generation 206, Max Fitness: 4, Max Score: 11
# Generation 207, Max Fitness: 4, Max Score: 11
# Generation 208, Max Fitness: 4, Max Score: 11
# Generation 209, Max Fitness: 4, Max Score: 11
# Generation 210, Max Fitness: 4, Max Score: 11
# Generation 211, Max Fitness: 4, Max Score: 11
# Generation 212, Max Fitness: 4, Max Score: 11
# Generation 213, Max Fitness: 10, Max Score: 11
# Generation 214, Max Fitness: 4, Max Score: 11
# Generation 215, Max Fitness: 4, Max Score: 11
# Generation 216, Max Fitness: 4, Max Score: 11
# Generation 217, Max Fitness: 4, Max Score: 11
# Generation 218, Max Fitness: 4, Max Score: 11
# Generation 219, Max Fitness: 9, Max Score: 11
# Generation 220, Max Fitness: 4, Max Score: 11
# Generation 221, Max Fitness: 4, Max Score: 11
# Generation 222, Max Fitness: 4, Max Score: 11
# Generation 223, Max Fitness: 9, Max Score: 11
# Generation 224, Max Fitness: 9, Max Score: 11
# Generation 225, Max Fitness: 4, Max Score: 11
# Generation 226, Max Fitness: 4, Max Score: 11
# Generation 227, Max Fitness: 4, Max Score: 11
# Generation 228, Max Fitness: 10, Max Score: 11
# Generation 229, Max Fitness: 10, Max Score: 11
# Generation 230, Max Fitness: 4, Max Score: 11
# Generation 231, Max Fitness: 4, Max Score: 11
# Generation 232, Max Fitness: 4, Max Score: 11
# Generation 233, Max Fitness: 4, Max Score: 11
# Generation 234, Max Fitness: 9, Max Score: 11
# Generation 235, Max Fitness: 4, Max Score: 11
# Generation 236, Max Fitness: 4, Max Score: 11
# Generation 237, Max Fitness: 9, Max Score: 11
# Generation 238, Max Fitness: 4, Max Score: 11
# Generation 239, Max Fitness: 4, Max Score: 11
# Generation 240, Max Fitness: 7, Max Score: 11
# Generation 241, Max Fitness: 4, Max Score: 11
# Generation 242, Max Fitness: 4, Max Score: 11
# Generation 243, Max Fitness: 11, Max Score: 11
# Generation 244, Max Fitness: 4, Max Score: 11
# Generation 245, Max Fitness: 9, Max Score: 11
# Generation 246, Max Fitness: 11, Max Score: 11
# Generation 247, Max Fitness: 4, Max Score: 11
# Generation 248, Max Fitness: 4, Max Score: 11
# Generation 249, Max Fitness: 10, Max Score: 11
# Generation 250, Max Fitness: 4, Max Score: 11
# Generation 251, Max Fitness: 4, Max Score: 11
# Generation 252, Max Fitness: 4, Max Score: 11
# Generation 253, Max Fitness: 4, Max Score: 11
# Generation 254, Max Fitness: 4, Max Score: 11
# Generation 255, Max Fitness: 4, Max Score: 11
# Generation 256, Max Fitness: 4, Max Score: 11
# Generation 257, Max Fitness: 10, Max Score: 11
# Generation 258, Max Fitness: 10, Max Score: 11
# Generation 259, Max Fitness: 4, Max Score: 11
# Generation 260, Max Fitness: 4, Max Score: 11
# Generation 261, Max Fitness: 4, Max Score: 11
# Generation 262, Max Fitness: 4, Max Score: 11
# Generation 263, Max Fitness: 10, Max Score: 11
# Generation 264, Max Fitness: 10, Max Score: 11
# Generation 265, Max Fitness: 4, Max Score: 11
# Generation 266, Max Fitness: 4, Max Score: 11
# Generation 267, Max Fitness: 4, Max Score: 11
# Generation 268, Max Fitness: 4, Max Score: 11
# Generation 269, Max Fitness: 4, Max Score: 11
# Generation 270, Max Fitness: 10, Max Score: 11
# Generation 271, Max Fitness: 4, Max Score: 11
# Generation 272, Max Fitness: 4, Max Score: 11
# Generation 273, Max Fitness: 10, Max Score: 11
# Generation 274, Max Fitness: 11, Max Score: 11
# Generation 275, Max Fitness: 4, Max Score: 11
# Generation 276, Max Fitness: 4, Max Score: 11
# Generation 277, Max Fitness: 10, Max Score: 11
# Generation 278, Max Fitness: 4, Max Score: 11
# Generation 279, Max Fitness: 4, Max Score: 11
# Generation 280, Max Fitness: 4, Max Score: 11
# Generation 281, Max Fitness: 10, Max Score: 11
# Generation 282, Max Fitness: 4, Max Score: 11
# Generation 283, Max Fitness: 4, Max Score: 11
# Generation 284, Max Fitness: 9, Max Score: 11
# Generation 285, Max Fitness: 4, Max Score: 11
# Generation 286, Max Fitness: 4, Max Score: 11
# Generation 287, Max Fitness: 4, Max Score: 11
# Generation 288, Max Fitness: 4, Max Score: 11
# Generation 289, Max Fitness: 4, Max Score: 11
# Generation 290, Max Fitness: 4, Max Score: 11
# Generation 291, Max Fitness: 4, Max Score: 11
# Generation 292, Max Fitness: 4, Max Score: 11
# Generation 293, Max Fitness: 4, Max Score: 11
# Generation 294, Max Fitness: 4, Max Score: 11
# Generation 295, Max Fitness: 4, Max Score: 11
# Generation 296, Max Fitness: 4, Max Score: 11
# Generation 297, Max Fitness: 4, Max Score: 11
# Generation 298, Max Fitness: 4, Max Score: 11
# Generation 299, Max Fitness: 11, Max Score: 11
# Generation 300, Max Fitness: 4, Max Score: 11
# Generation 301, Max Fitness: 4, Max Score: 11
# Generation 302, Max Fitness: 4, Max Score: 11
# Generation 303, Max Fitness: 4, Max Score: 11
# Generation 304, Max Fitness: 4, Max Score: 11
# Generation 305, Max Fitness: 11, Max Score: 11
# Generation 306, Max Fitness: 4, Max Score: 11
# Generation 307, Max Fitness: 4, Max Score: 11
# Generation 308, Max Fitness: 4, Max Score: 11
# Generation 309, Max Fitness: 4, Max Score: 11
# Generation 310, Max Fitness: 4, Max Score: 11
# Generation 311, Max Fitness: 4, Max Score: 11
# Generation 312, Max Fitness: 4, Max Score: 11
# Generation 313, Max Fitness: 4, Max Score: 11
# Generation 314, Max Fitness: 4, Max Score: 11
# Generation 315, Max Fitness: 4, Max Score: 11
# Generation 316, Max Fitness: 9, Max Score: 11
# Generation 317, Max Fitness: 4, Max Score: 11
# Generation 318, Max Fitness: 9, Max Score: 11
# Generation 319, Max Fitness: 4, Max Score: 11
# Generation 320, Max Fitness: 4, Max Score: 11
# Generation 321, Max Fitness: 11, Max Score: 11
# Generation 322, Max Fitness: 4, Max Score: 11
# Generation 323, Max Fitness: 4, Max Score: 11
# Generation 324, Max Fitness: 4, Max Score: 11
# Generation 325, Max Fitness: 4, Max Score: 11
# Generation 326, Max Fitness: 4, Max Score: 11
# Generation 327, Max Fitness: 4, Max Score: 11
# Generation 328, Max Fitness: 4, Max Score: 11
# Generation 329, Max Fitness: 4, Max Score: 11
# Generation 330, Max Fitness: 4, Max Score: 11
# Generation 331, Max Fitness: 10, Max Score: 11
# Generation 332, Max Fitness: 4, Max Score: 11
# Generation 333, Max Fitness: 4, Max Score: 11
# Generation 334, Max Fitness: 4, Max Score: 11
# Generation 335, Max Fitness: 10, Max Score: 11
# Generation 336, Max Fitness: 4, Max Score: 11
# Generation 337, Max Fitness: 4, Max Score: 11
# Generation 338, Max Fitness: 4, Max Score: 11
# Generation 339, Max Fitness: 4, Max Score: 11
# Generation 340, Max Fitness: 4, Max Score: 11
# Generation 341, Max Fitness: 9, Max Score: 11
# Generation 342, Max Fitness: 4, Max Score: 11
# Generation 343, Max Fitness: 10, Max Score: 11
# Generation 344, Max Fitness: 4, Max Score: 11
# Generation 345, Max Fitness: 4, Max Score: 11
# Generation 346, Max Fitness: 4, Max Score: 11
# Generation 347, Max Fitness: 4, Max Score: 11
# Generation 348, Max Fitness: 11, Max Score: 11
# Generation 349, Max Fitness: 11, Max Score: 11
# Generation 350, Max Fitness: 4, Max Score: 11
# Generation 351, Max Fitness: 4, Max Score: 11
# Generation 352, Max Fitness: 4, Max Score: 11
# Generation 353, Max Fitness: 4, Max Score: 11
# Generation 354, Max Fitness: 4, Max Score: 11
# Generation 355, Max Fitness: 4, Max Score: 11
# Generation 356, Max Fitness: 4, Max Score: 11
# Generation 357, Max Fitness: 10, Max Score: 11
# Generation 358, Max Fitness: 4, Max Score: 11
# Generation 359, Max Fitness: 11, Max Score: 11
# Generation 360, Max Fitness: 4, Max Score: 11
# Generation 361, Max Fitness: 4, Max Score: 11
# Generation 362, Max Fitness: 4, Max Score: 11
# Generation 363, Max Fitness: 4, Max Score: 11
# Generation 364, Max Fitness: 4, Max Score: 11
# Generation 365, Max Fitness: 4, Max Score: 11
# Generation 366, Max Fitness: 10, Max Score: 11
# Generation 367, Max Fitness: 4, Max Score: 11
# Generation 368, Max Fitness: 4, Max Score: 11
# Generation 369, Max Fitness: 4, Max Score: 11
# Generation 370, Max Fitness: 9, Max Score: 11
# Generation 371, Max Fitness: 11, Max Score: 11
# Generation 372, Max Fitness: 4, Max Score: 11
# Generation 373, Max Fitness: 4, Max Score: 11
# Generation 374, Max Fitness: 4, Max Score: 11
# Generation 375, Max Fitness: 4, Max Score: 11
# Generation 376, Max Fitness: 4, Max Score: 11
# Generation 377, Max Fitness: 11, Max Score: 11
# Generation 378, Max Fitness: 9, Max Score: 11
# Generation 379, Max Fitness: 4, Max Score: 11
# Generation 380, Max Fitness: 4, Max Score: 11
# Generation 381, Max Fitness: 4, Max Score: 11
# Generation 382, Max Fitness: 11, Max Score: 11
# Generation 383, Max Fitness: 4, Max Score: 11
# Generation 384, Max Fitness: 4, Max Score: 11
# Generation 385, Max Fitness: 4, Max Score: 11
# Generation 386, Max Fitness: 4, Max Score: 11
# Generation 387, Max Fitness: 4, Max Score: 11
# Generation 388, Max Fitness: 4, Max Score: 11
# Generation 389, Max Fitness: 11, Max Score: 11
# Generation 390, Max Fitness: 4, Max Score: 11
# Generation 391, Max Fitness: 4, Max Score: 11
# Generation 392, Max Fitness: 9, Max Score: 11
# Generation 393, Max Fitness: 11, Max Score: 11
# Generation 394, Max Fitness: 4, Max Score: 11
# Generation 395, Max Fitness: 9, Max Score: 11
# Generation 396, Max Fitness: 4, Max Score: 11
# Generation 397, Max Fitness: 10, Max Score: 11
# Generation 398, Max Fitness: 4, Max Score: 11
# Generation 399, Max Fitness: 10, Max Score: 11
# Generation 400, Max Fitness: 4, Max Score: 11
# Generation 401, Max Fitness: 4, Max Score: 11
# Generation 402, Max Fitness: 4, Max Score: 11
# Generation 403, Max Fitness: 4, Max Score: 11
# Generation 404, Max Fitness: 4, Max Score: 11
# Generation 405, Max Fitness: 4, Max Score: 11
# Generation 406, Max Fitness: 4, Max Score: 11
# Generation 407, Max Fitness: 4, Max Score: 11
# Generation 408, Max Fitness: 4, Max Score: 11
# Generation 409, Max Fitness: 4, Max Score: 11
# Generation 410, Max Fitness: 4, Max Score: 11
# Generation 411, Max Fitness: 4, Max Score: 11
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 main()
#
# Cell In[7], line 17, in main()
#      15 max_score = 0
#      16 for generation in range(generations):
# ---> 17     max_fitness = ea.run_generation(screen=None, maximum=100)
#      18     print(f"Generation {generation}, Max Fitness: {max_fitness}, Max Score: {max_score}")
#      19     if max_fitness > max_score:
#
# Cell In[6], line 32, in EvolutionaryAlgorithm.run_generation(self, screen, maximum)
#      30 def run_generation(self, screen=None, maximum=False):
#      31     # Evaluate fitness of each network
# ---> 32     fitness_scores = [self.evaluate_fitness(network, screen=screen, maximum=maximum) for network in self.population]
#      34     # Select top-performing networks
#      35     sorted_population = [network for _, network in sorted(zip(fitness_scores, self.population), key=lambda tuple: tuple[0], reverse=True)]
#
# Cell In[6], line 13, in EvolutionaryAlgorithm.evaluate_fitness(self, network, screen, maximum)
#      11 while game.alive:
#      12     inputs = game.get_input()
# ---> 13     outputs = network.forward(inputs)
#      14     total += np.sum(outputs)
#      15     game.step(outputs[0])
#
# Cell In[4], line 46, in RecurrentSpikingNeuralNetwork.forward(self, inputs)
#      44 in_weighted = (self.input_matrix @ in_vec).reshape(-1) # Calculate and make it a 1d array for ease of looping
#      45 for i, input in enumerate(in_weighted):
# ---> 46     self.neurons[i].receive_input(input)
#      48 # All connections are resolved
#      49 con_vec = self.spikes.reshape(-1,1) # Turn inputs into a vertical vector
#
# Cell In[3], line 7, in SpikingNeuron.receive_input(self, input_value)
#       4     self.threshold = threshold
#       5     self.decay = decay
# ----> 7 def receive_input(self, input_value):
#       8     self.potential += input_value
#      10 def step(self):
#      11     # Neuron fires if potential exceeds threshold
#
# KeyboardInterrupt:
